# %%
import json
import pandas as pd

# %%
file_path = '/content/sennheiser_data.json'
with open(file_path, 'r') as file:
    data = json.load(file)

# %%
reviews_data = []
count = 0
for result in data['results']:
  asin = result['content']["asin"]
  for review in result['content']['reviews']:
    count += 1
    try:
      review_info = {
      'review_id': review['id'],
      'product_id': asin,
      "title": review["title"],
      "author": review["author"],
      "rating": review["author"],
      "content": review["content"],
      "timestamp": review["timestamp"],
      "profile_id": review["profile_id"],
      "is_verified": review["is_verified"],
      "helpful_count": review.get('helpful_count', 0),
      "product_attributes": review["product_attributes"]
      }
      reviews_data.append(review_info)
    except:
      print(count)
      break

reviews_df = pd.DataFrame(reviews_data)
reviews_df.to_csv('reviews_sennheiser.csv', index=False)

reviews_df
# Out:
#          review_id  product_id  \
# 0   R1AC58E4VI0C2P  B0B6GHW1SX
# 1   R1FU9D18YOSOS6  B0B6GHW1SX
# 2   R1IVGTBWY7A3K4  B0B6GHW1SX
# 3   R2CIT7PKP36F3M  B0B6GHW1SX
# 4   R27AA754NCZRA9  B0B6GHW1SX
# ..             ...         ...
# 95  R1GYWB9KZ2D838  B0B6GHW1SX
# 96  R2KLVLJ9CKHB23  B0B6GHW1SX
# 97  R3MLB87WJ62LQT  B0B6GHW1SX
# 98  R1D185K9ZFHJBP  B0B6GHW1SX
# 99  R11GZHKSG7BTMU  B0B6GHW1SX
#
#                                                 title               author  \
# 0                5.0 out of 5 stars Music to my ears!                 DDAY
# 1   5.0 out of 5 stars Ignore the complaints, thes...           MA Stewart
# 2   5.0 out of 5 stars First Sennheiser purchase, ...        Shara Simpson
# 3   4.0 out of 5 stars Exceptional sound quality, ...      Amazon Customer
# 4    3.0 out of 5 stars Good on paper, bad on my head                  Sam
# ..                                                ...                  ...
# ...

# %%
df_1 = pd.read_csv('/content/reviews_beats.csv')
df_2 = pd.read_csv('/content/reviews_jbl.csv')
df_3 = pd.read_csv('/content/reviews_sony.csv')
df_4 = pd.read_csv('/content/reviews_anker.csv')
df_5 = pd.read_csv('/content/reviews_skullcandy.csv')
df_6 = pd.read_csv('/content/reviews_beribes.csv')
df_7 = pd.read_csv('/content/reviews_doquas.csv')
df_8 = pd.read_csv('/content/reviews_kvidio.csv')
df_9 = pd.read_csv('/content/reviews_marshall.csv')
df_10 = pd.read_csv('/content/reviews_sennheiser.csv')


df_2.head()
# Out:
#         review_id  product_id  \
# 0  R2JZRUSGEPSHDD  B08WM3LMJF
# 1  R3IYM5KVQJSBK6  B08WM3LMJF
# 2  R3Q3OO4BZN2QYX  B08WM3LMJF
# 3   RMAOYF9V6ORGD  B08WM3LMJF
# 4  R30DK0GQHFZ7LL  B08WM3LMJF
#
#                                                title             author  \
# 0    5.0 out of 5 stars Such a great value, I got 3!     Sherae Collado
# 1        5.0 out of 5 stars Charge lasts a long time           LisaFayD
# 2        5.0 out of 5 stars Great set of headphones!  Marcus Sutherland
# 3  4.0 out of 5 stars Solid Performance with a Fe...          Art Bowen
# 4  5.0 out of 5 stars A good headset for a great ...       Mom Griswold
#
#               rating                                            content  \
# 0     Sherae Collado  I needed new headphones and so did my boys. We...
# 1           LisaFayD  I got two pair of these. One was a thank you p...
# 2  Marcus Sutherland  I was very pleased with this set of headphones...
# ...

# %%
merged_df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10], ignore_index=True)
merged_df
# Out:
#           review_id  product_id  \
# 0     RAI90QWJQJF03  B0CCBKGDJD
# 1    R1MJ08QRWZKAK6  B0CCBKGDJD
# 2    R2IQV1A1SCQDVZ  B0CCBKGDJD
# 3     RB86XLAVC3GP7  B0CCBKGDJD
# 4    R2Z4K7Q4FQDJMI  B0CCBKGDJD
# ..              ...         ...
# 995  R1GYWB9KZ2D838  B0B6GHW1SX
# 996  R2KLVLJ9CKHB23  B0B6GHW1SX
# 997  R3MLB87WJ62LQT  B0B6GHW1SX
# 998  R1D185K9ZFHJBP  B0B6GHW1SX
# 999  R11GZHKSG7BTMU  B0B6GHW1SX
#
#                                                  title               author  \
# 0    5.0 out of 5 stars Literally mind-blowing upgr...    Christian Waymire
# 1                  5.0 out of 5 stars My Go-to Headset           Amiyah Ogo
# 2    5.0 out of 5 stars These headphones deserve th...       Mariah Chapman
# 3            5.0 out of 5 stars 10/10, would buy again                 Nala
# 4                          5.0 out of 5 stars Worth it                kwine
# ..                                                 ...                  ...
# ...

# %%
merged_df.to_csv('all_reviews.csv', index=False)
